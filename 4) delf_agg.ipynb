# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import argparse
import csv
import os
import sys
import time

import numpy as np
import tensorflow as tf

from google.protobuf import text_format
from tensorflow.python.platform import app
from delf import aggregation_config_pb2
from delf import datum_io
from delf import feature_aggregation_extractor
from delf import feature_io
from delf.python.detect_to_retrieve import dataset

import traceback
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.

# %%
# Aliases for aggregation types.
_VLAD = aggregation_config_pb2.AggregationConfig.VLAD
_ASMK = aggregation_config_pb2.AggregationConfig.ASMK
_ASMK_STAR = aggregation_config_pb2.AggregationConfig.ASMK_STAR

# Extensions.
_DELF_EXTENSION = '.delf'
_VLAD_EXTENSION_SUFFIX = 'vlad'
_ASMK_EXTENSION_SUFFIX = 'asmk'
_ASMK_STAR_EXTENSION_SUFFIX = 'asmk_star'



# Pace to report extraction log.
_STATUS_CHECK_ITERATIONS = 50

# %%
#QUERY일 경우, 그리고 INDEX일 경우 ################ 이부분 동적변경필요
IS_QUERY = False

OUTPUT_QUERY = 'output/agg/query'
OUTPUT_INDEX = 'output/agg/index'

# %%
def _ReadMappingBasenameToBoxNames(input_path, index_image_names):
    """Reads mapping from image name to DELF file names for each box.

    Args:
        input_path: Path to CSV file containing mapping.
        index_image_names: List containing index image names, in order, for the
            dataset under consideration.

    Returns:
        images_to_box_feature_files: Dict. key=string (image name); value=list of
            strings (file names containing DELF features for boxes).
    """
    images_to_box_feature_files = {}
    with tf.gfile.GFile(input_path, 'r') as f:
        reader = csv.DictReader(f)
        for row in reader:
            index_image_name = index_image_names[int(row['index_image_id'])]
            if index_image_name not in images_to_box_feature_files:
                images_to_box_feature_files[index_image_name] = []

            images_to_box_feature_files[index_image_name].append(row['name'])

    return images_to_box_feature_files

# %%
# Read list of images from dataset file.
print('Reading list of images from dataset file...')

if IS_QUERY:
    image_list = os.listdir("image_test")
else:
    image_list = os.listdir("image_index")
    
num_images = len(image_list)
print('done! Found %d images' % num_images)
# Out:
# Reading list of images from dataset file...
# done! Found 7618 images

# %%
# Parse AggregationConfig proto, and select output extension.
config = aggregation_config_pb2.AggregationConfig()

if IS_QUERY:
    with tf.gfile.GFile('query_aggregation_config.pbtxt', 'r') as f:
        text_format.Merge(f.read(), config)
else:
    with tf.gfile.GFile('index_aggregation_config.pbtxt', 'r') as f:
        text_format.Merge(f.read(), config)

# %%
output_extension = '.'
if config.use_regional_aggregation:
    output_extension += 'r'
if config.aggregation_type == _VLAD:
    output_extension += _VLAD_EXTENSION_SUFFIX
elif config.aggregation_type == _ASMK:
    output_extension += _ASMK_EXTENSION_SUFFIX
elif config.aggregation_type == _ASMK_STAR:
    output_extension += _ASMK_STAR_EXTENSION_SUFFIX
else:
    raise ValueError('Invalid aggregation type: %d' % config.aggregation_type)

# %%
# Read index mapping path, if provided.
if IS_QUERY == False:
    images_to_box_feature_files = _ReadMappingBasenameToBoxNames('index_mapping_1.csv', image_list)

# %%
output_dir = ""

if IS_QUERY:
    output_dir = OUTPUT_QUERY
    if not os.path.exists(OUTPUT_QUERY):
        os.makedirs(OUTPUT_QUERY)
else:
    output_dir = OUTPUT_INDEX
    if not os.path.exists(OUTPUT_INDEX):
        os.makedirs(OUTPUT_INDEX)

# %%
with tf.Session() as sess:
    extractor = feature_aggregation_extractor.ExtractAggregatedRepresentation(sess, config)

    start = time.clock()
    for i in range(num_images):
        if i == 0:
            print('Starting to extract aggregation from images...')
        elif i % _STATUS_CHECK_ITERATIONS == 0:
            elapsed = (time.clock() - start)
            print('Processing image %d out of %d, last %d '
                        'images took %f seconds' %
                        (i, num_images, _STATUS_CHECK_ITERATIONS, elapsed))
            start = time.clock()

        image_name = image_list[i]

        output_aggregation_filename = os.path.join(output_dir, image_name + output_extension)
        if tf.io.gfile.exists(output_aggregation_filename):
            print('Skipping %s' % image_name)
            continue

        # Load DELF features.
        if config.use_regional_aggregation:
            if not 'index_mapping_1.csv':
                raise ValueError(
                        'Requested regional aggregation, but index_mapping_path was not '
                        'provided')
            descriptors_list = []
            num_features_per_box = []
            for box_feature_file in images_to_box_feature_files[image_name]:
                
                try :
                
                    delf_filename = os.path.join(FEATURE_FILE_PATH, box_feature_file + _DELF_EXTENSION)
                    _, _, box_descriptors, _, _ = feature_io.ReadFromFile(delf_filename)
                    # If `box_descriptors` is empty, reshape it such that it can be
                    # concatenated with other descriptors.
                    if not box_descriptors.shape[0]:
                        box_descriptors = np.reshape(box_descriptors,[0, config.feature_dimensionality])
                    descriptors_list.append(box_descriptors)
                    num_features_per_box.append(box_descriptors.shape[0])
                except :
                    traceback.print_exc()

            descriptors = np.concatenate(descriptors_list)
        else:
            input_delf_filename = os.path.join(FEATURE_FILE_PATH,image_name + _DELF_EXTENSION)
            _, _, descriptors, _, _ = feature_io.ReadFromFile(input_delf_filename)
            num_features_per_box = None

        # Extract and save aggregation. If using VLAD, only
        # `aggregated_descriptors` needs to be saved.
        (aggregated_descriptors,feature_visual_words) = extractor.Extract(descriptors,num_features_per_box)
        if config.aggregation_type == _VLAD:
            datum_io.WriteToFile(aggregated_descriptors,output_aggregation_filename)
        else:
            datum_io.WritePairToFile(aggregated_descriptors,feature_visual_words.astype('uint32'),output_aggregation_filename)
# Out:
# WARNING:tensorflow:From C:\Users\kohry\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Starting to extract aggregation from images...
# Skipping 0000215a37942b17.jpg
# Skipping 00005baad2e46555.jpg
# Skipping 00007d3b7f15b575.jpg
# Skipping 00009069e8450638.jpg
# Skipping 00009574f46e9fd8.jpg
# Skipping 0000b557ddd05437.jpg
# Skipping 0000b95ce4944983.jpg
# Skipping 0000c20fbe1211e1.jpg
# Skipping 0000e1e4efccba54.jpg
# Skipping 0000e5fdd18678af.jpg
# Skipping 00011c8a4e1b2ea0.jpg
# Skipping 000132b0b0db5bc8.jpg
# Skipping 0001389e2eb5272a.jpg
# Skipping 00013ee025f313ff.jpg
# Skipping 0001593e01060541.jpg
# Skipping 00016447d1d4a48b.jpg
# Skipping 00016c947d9aaf99.jpg
# Skipping 000177d70912e009.jpg
# Skipping 0001c49b3f75781f.jpg
# Skipping 0001e99724ddbf3b.jpg
# Skipping 0001f71d919b7ba4.jpg
# Skipping 0002451206958ed6.jpg
# Skipping 000248fc5040c9d4.jpg
FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# Processing image 200 out of 7618, last 50 images took 6.271507 seconds
# Processing image 250 out of 7618, last 50 images took 8.515938 seconds
# Processing image 300 out of 7618, last 50 images took 7.209456 seconds
# Processing image 350 out of 7618, last 50 images took 7.704443 seconds
# Processing image 400 out of 7618, last 50 images took 7.777167 seconds
# Processing image 450 out of 7618, last 50 images took 7.142771 seconds
# Processing image 500 out of 7618, last 50 images took 7.461291 seconds
# Processing image 550 out of 7618, last 50 images took 7.800984 seconds
# Processing image 600 out of 7618, last 50 images took 8.051051 seconds
# Processing image 650 out of 7618, last 50 images took 8.040888 seconds
# Processing image 700 out of 7618, last 50 images took 7.651775 seconds
# Processing image 750 out of 7618, last 50 images took 7.817021 seconds
# Processing image 800 out of 7618, last 50 images took 7.483591 seconds
# Processing image 850 out of 7618, last 50 images took 7.624336 seconds
# Processing image 900 out of 7618, last 50 images took 7.508788 seconds
# Processing image 950 out of 7618, last 50 images took 7.777854 seconds
# Processing image 1000 out of 7618, last 50 images took 7.515083 seconds
# Processing image 1050 out of 7618, last 50 images took 7.561856 seconds
# Processing image 1100 out of 7618, last 50 images took 7.488302 seconds
# Processing image 1150 out of 7618, last 50 images took 7.115682 seconds
# Processing image 1200 out of 7618, last 50 images took 8.193029 seconds
# Processing image 1250 out of 7618, last 50 images took 7.428844 seconds
# Processing image 1300 out of 7618, last 50 images took 7.659491 seconds
# Processing image 1350 out of 7618, last 50 images took 7.925370 seconds
# Processing image 1400 out of 7618, last 50 images took 8.024064 seconds
# Processing image 1450 out of 7618, last 50 images took 7.316008 seconds
# Processing image 1500 out of 7618, last 50 images took 7.890195 seconds
# Processing image 1550 out of 7618, last 50 images took 7.409489 seconds
# Processing image 1600 out of 7618, last 50 images took 7.842445 seconds
# Processing image 1650 out of 7618, last 50 images took 7.985383 seconds
# Processing image 1700 out of 7618, last 50 images took 7.620453 seconds
# Processing image 1750 out of 7618, last 50 images took 7.885953 seconds
# Processing image 1800 out of 7618, last 50 images took 8.186332 seconds
# Processing image 1850 out of 7618, last 50 images took 7.799862 seconds
# Processing image 1900 out of 7618, last 50 images took 7.332623 seconds
# Processing image 1950 out of 7618, last 50 images took 7.697831 seconds
# Processing image 2000 out of 7618, last 50 images took 7.431558 seconds
# Processing image 2050 out of 7618, last 50 images took 7.275073 seconds
# Processing image 2100 out of 7618, last 50 images took 7.948649 seconds
# Processing image 2150 out of 7618, last 50 images took 7.119347 seconds
# Processing image 2200 out of 7618, last 50 images took 8.136994 seconds
# Processing image 2250 out of 7618, last 50 images took 8.020020 seconds
# Processing image 2300 out of 7618, last 50 images took 7.519684 seconds
# Processing image 2350 out of 7618, last 50 images took 7.500149 seconds
# Processing image 2400 out of 7618, last 50 images took 8.012218 seconds
# Processing image 2450 out of 7618, last 50 images took 8.146642 seconds
# Processing image 2500 out of 7618, last 50 images took 7.687543 seconds
# Processing image 2550 out of 7618, last 50 images took 7.087634 seconds
# Processing image 2600 out of 7618, last 50 images took 6.828612 seconds
# Processing image 2650 out of 7618, last 50 images took 6.923410 seconds
# Processing image 2700 out of 7618, last 50 images took 7.615502 seconds
# Processing image 2750 out of 7618, last 50 images took 7.042295 seconds
# Processing image 2800 out of 7618, last 50 images took 7.805500 seconds
# Processing image 2850 out of 7618, last 50 images took 6.999692 seconds
# Processing image 2900 out of 7618, last 50 images took 7.726455 seconds
# Processing image 2950 out of 7618, last 50 images took 7.582278 seconds
# Processing image 3000 out of 7618, last 50 images took 7.228720 seconds
# Processing image 3050 out of 7618, last 50 images took 7.382772 seconds
# Processing image 3100 out of 7618, last 50 images took 7.602442 seconds
# Processing image 3150 out of 7618, last 50 images took 7.280366 seconds
# Processing image 3200 out of 7618, last 50 images took 7.373606 seconds
# Processing image 3250 out of 7618, last 50 images took 7.418580 seconds
# Processing image 3300 out of 7618, last 50 images took 7.410664 seconds
# Processing image 3350 out of 7618, last 50 images took 7.265849 seconds
# Processing image 3400 out of 7618, last 50 images took 7.195715 seconds
# Processing image 3450 out of 7618, last 50 images took 7.195612 seconds
# Processing image 3500 out of 7618, last 50 images took 7.366419 seconds
# Processing image 3550 out of 7618, last 50 images took 6.998518 seconds
# Processing image 3600 out of 7618, last 50 images took 7.717708 seconds
# Processing image 3650 out of 7618, last 50 images took 7.308688 seconds
# Processing image 3700 out of 7618, last 50 images took 7.818500 seconds
# Processing image 3750 out of 7618, last 50 images took 7.265699 seconds
# Processing image 3800 out of 7618, last 50 images took 7.737962 seconds
# Processing image 3850 out of 7618, last 50 images took 7.587694 seconds
# Processing image 3900 out of 7618, last 50 images took 7.950600 seconds
# Processing image 3950 out of 7618, last 50 images took 7.004663 seconds
# Processing image 4000 out of 7618, last 50 images took 7.279804 seconds
# Processing image 4050 out of 7618, last 50 images took 6.321971 seconds
# Processing image 4100 out of 7618, last 50 images took 7.978772 seconds
# Processing image 4150 out of 7618, last 50 images took 7.828053 seconds
# Processing image 4200 out of 7618, last 50 images took 8.252072 seconds
# Processing image 4250 out of 7618, last 50 images took 7.147199 seconds
# Processing image 4300 out of 7618, last 50 images took 7.994145 seconds
# Processing image 4350 out of 7618, last 50 images took 7.499519 seconds
# Processing image 4400 out of 7618, last 50 images took 7.194318 seconds
# Processing image 4450 out of 7618, last 50 images took 6.903875 seconds
# Processing image 4500 out of 7618, last 50 images took 7.434439 seconds
# Processing image 4550 out of 7618, last 50 images took 7.537974 seconds
# Processing image 4600 out of 7618, last 50 images took 7.162038 seconds
# Processing image 4650 out of 7618, last 50 images took 7.390230 seconds
# Processing image 4700 out of 7618, last 50 images took 7.569874 seconds
# Processing image 4750 out of 7618, last 50 images took 7.799125 seconds
# Processing image 4800 out of 7618, last 50 images took 7.547051 seconds
# Processing image 4850 out of 7618, last 50 images took 7.634357 seconds
# Processing image 4900 out of 7618, last 50 images took 7.828462 seconds
# Processing image 4950 out of 7618, last 50 images took 8.220339 seconds
# Processing image 5000 out of 7618, last 50 images took 7.008767 seconds
# Processing image 5050 out of 7618, last 50 images took 7.022741 seconds
# Processing image 5100 out of 7618, last 50 images took 7.965195 seconds
# Processing image 5150 out of 7618, last 50 images took 7.232495 seconds
# Processing image 5200 out of 7618, last 50 images took 7.652715 seconds
# Processing image 5250 out of 7618, last 50 images took 7.619920 seconds
# Processing image 5300 out of 7618, last 50 images took 7.290862 seconds
# Processing image 5350 out of 7618, last 50 images took 7.532012 seconds
# Processing image 5400 out of 7618, last 50 images took 7.076774 seconds
# Processing image 5450 out of 7618, last 50 images took 7.636328 seconds
# Processing image 5500 out of 7618, last 50 images took 7.367329 seconds
# Processing image 5550 out of 7618, last 50 images took 7.366694 seconds
# Processing image 5600 out of 7618, last 50 images took 7.709040 seconds
# Processing image 5650 out of 7618, last 50 images took 7.744161 seconds
# Processing image 5700 out of 7618, last 50 images took 7.251330 seconds
# Processing image 5750 out of 7618, last 50 images took 7.338051 seconds
# Processing image 5800 out of 7618, last 50 images took 7.646163 seconds
# Processing image 5850 out of 7618, last 50 images took 7.370565 seconds
# Processing image 5900 out of 7618, last 50 images took 7.207917 seconds
# Processing image 5950 out of 7618, last 50 images took 7.664849 seconds
# Processing image 6000 out of 7618, last 50 images took 7.713135 seconds
# Processing image 6050 out of 7618, last 50 images took 7.470574 seconds
# Processing image 6100 out of 7618, last 50 images took 7.440449 seconds
# Processing image 6150 out of 7618, last 50 images took 8.032397 seconds
# Processing image 6200 out of 7618, last 50 images took 7.395168 seconds
# Processing image 6250 out of 7618, last 50 images took 7.546904 seconds
# Processing image 6300 out of 7618, last 50 images took 8.526305 seconds
# Processing image 6350 out of 7618, last 50 images took 7.599253 seconds
# Processing image 6400 out of 7618, last 50 images took 8.134394 seconds
# Processing image 6450 out of 7618, last 50 images took 7.324074 seconds
# Processing image 6500 out of 7618, last 50 images took 7.452494 seconds
# Processing image 6550 out of 7618, last 50 images took 7.896539 seconds
# Processing image 6600 out of 7618, last 50 images took 7.925022 seconds
# Processing image 6650 out of 7618, last 50 images took 7.727983 seconds
# Processing image 6700 out of 7618, last 50 images took 7.352260 seconds
# Processing image 6750 out of 7618, last 50 images took 8.036210 seconds
# Processing image 6800 out of 7618, last 50 images took 7.634212 seconds
# Processing image 6850 out of 7618, last 50 images took 7.584378 seconds
# Processing image 6900 out of 7618, last 50 images took 8.179915 seconds
# Processing image 6950 out of 7618, last 50 images took 7.476569 seconds
# Processing image 7000 out of 7618, last 50 images took 7.647518 seconds
# Processing image 7050 out of 7618, last 50 images took 7.886809 seconds
# Processing image 7100 out of 7618, last 50 images took 7.854878 seconds
# Processing image 7150 out of 7618, last 50 images took 7.735803 seconds
# Processing image 7200 out of 7618, last 50 images took 7.740885 seconds
# Processing image 7250 out of 7618, last 50 images took 7.890146 seconds
# Processing image 7300 out of 7618, last 50 images took 7.496275 seconds
# Processing image 7350 out of 7618, last 50 images took 8.003265 seconds
# Processing image 7400 out of 7618, last 50 images took 7.857566 seconds
# Processing image 7450 out of 7618, last 50 images took 8.081946 seconds
# Processing image 7500 out of 7618, last 50 images took 8.282517 seconds
# Processing image 7550 out of 7618, last 50 images took 7.181470 seconds
# Processing image 7600 out of 7618, last 50 images took 8.076209 seconds
